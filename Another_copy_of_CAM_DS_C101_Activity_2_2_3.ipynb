# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukanya1901/CAM_DS/blob/main/Another_copy_of_CAM_DS_C101_Activity_2_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **First things first** - please go to 'File' and select 'Save a copy in Drive' so that you have your own version of this activity set up and ready to use.
# Remember to update your Course 1 notebook with links to your own work once completed!

# %% [markdown]
# # Activity 2.2.3 Interpreting correlation
#
# ## Scenario
# You are a data analyst working for a large investment firm in London. The organisation is considering offering medical insurance as an employment benefit, but the management team needs to consider the potential cost of claims before they make any decisions. The team has received quotes from five medical insurers, and the cost of the insurance varies widely.
#
# One insurer has delivered a very competitive quote, but the downside is that the cost per person would vary depending on certain criteria set by the insurance company. These criteria include body mass index (BMI). The insurance would be affordable for all those with a BMI in the range of 18–24, but any employee outside of these categories would have to pay an additional monthly contribution. This may lead to the management team being accused of bias against these employees, as some employees would receive free insurance while others would have to pay.
#
# Your company is considering developing more targeted insurance plans and policies based on individual lifestyles. This would involve offering incentives for healthier living or adjusting premiums based on certain lifestyle choices. However, before implementing these changes, the company wants to gather evidence of any correlations between lifestyle choices and insurance costs.
#
# Your organisation would like to be able to evidence the impact of lifestyle choices on the medical insurance costs so that it can explain why some employees would have to pay extra to be in the scheme. To gather this evidence, it would like to explore the correlations between lifestyle choices and potential insurance costs.
#
# Your goal is to identify correlations in an anonymised data set that contains information about individuals and their medical insurance costs. The data set includes demographic data (age) and health and lifestyle data (BMI, and number of children). The management team would like you to explore which of these factors would have a significant effect on insurance costs.
#
#
# ## Objective
# Your goal is to identify correlations in an anonymised data set that contains information about individuals and their medical insurance costs.
#
#
# ## Assessment criteria
# By completing this activity, you will be able to provide evidence that you can:
# *   Investigate data systematically to identify links and account for biases.
# *   Interpret statistical test results rigorously, identifying and addressing assumptions and limitations
#
#
# ## Activity guide
# 1. **Libraries and data:**
# Import the necessary Python libraries and run the cell to load the data set.
# 2. **Data exploration:**
# Explore the data set.
# Calculate descriptive statistics and create visualisations (scatter plots, histograms, etc.).
# Gain a general understanding of the data.
# 3. **Statistical testing:**
# Conduct a correlation analysis on the specified variables using Python libraries such as Pandas and NumPy.
# Calculate correlation coefficients (e.g. Pearson or Spearman) and p-values.
# 4. **Interpretation:**
# Interpret the correlation coefficients and p-values.
# 5. **State limitations:**
# Describe the limitations of correlation analysis.
# Consider potential biases affecting interpretation.
# 6. **Reflecting and documenting:**
# Reflect on findings.
# Describe the entire analysis process, including exploration, statistical testing, and interpretation.
# Mention any assumptions and limitations in the analysis.

# %% [markdown]
# > Start your activity here. Select the pen from the toolbar to add your entry.

# %%
# Import libraries
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt #Visualisation
import seaborn as sns #Visualisation

data = pd.read_csv("https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/main/insurance_updated.csv")

# %%
data.head()
# Out:
#    age    bmi  number_of_children  charges
# 0   47  29.45                   1    25000
# 1   34  32.14                   0    24666
# 2   39  21.62                   1    18301
# 3   52  25.84                   1    19252
# 4   48  26.82                   1    24014

# %%
data.describe()
# Out:
#                age         bmi  number_of_children       charges
# count  1000.000000  1000.00000         1000.000000   1000.000000
# mean     29.674000    25.35935            0.966000  24634.033000
# std       8.800749     6.96078            0.932584   7766.545578
# min      18.000000    15.00000            0.000000  10858.000000
# 25%      22.750000    19.76750            0.000000  18758.000000
# 50%      29.000000    25.20500            1.000000  23970.000000
# 75%      36.000000    30.00250            2.000000  29200.750000
# max      57.000000    40.00000            4.000000  50597.000000

# %%
# Create a scatter plot
sns.scatterplot(data=data, x="number_of_children", y="charges")
plt.show()

# %%
# Create a scatter plot
sns.scatterplot(data=data, x="bmi", y="charges")
plt.show()

# %%
from scipy.stats import pearsonr

# data
x = data.loc[:, "number_of_children"]
y = data.loc[:, "charges"]

# Calculate Pearson correlation coefficient and p-value
correlation_coefficient, p_value = pearsonr(x, y)

print("Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# Correlation Coefficient: 0.0307081022349189
# p-value: 0.33200178686830395

# %% [markdown]
# Interpretation of strength and direction:
#
# The correlation coefficient is close to zero (0.031). This means there is no meaningful linear relationship between number of children and insurance charges.
#
# Statistical significance:
#
# The p-value (0.332) is much greater than 0.05, so the result is not statistically significant.

# %%
from scipy.stats import pearsonr

# data
x = data.loc[:, "bmi"]
y = data.loc[:, "charges"]

# Calculate Pearson correlation coefficient and p-value
correlation_coefficient, p_value = pearsonr(x, y)

print("Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# Correlation Coefficient: 0.7087713530017028
# p-value: 2.0579566103104821e-153

# %% [markdown]
# Interpretation of relationship:
#
# The coefficient is positive (0.709). As BMI increases, insurance charges also increase.
#
# Statistical significance:
#
# The p-value is extremely small (much smaller than 0.05). This means the probability of observing this correlation being random is almost zero.
#
# Therefore, the correlation is statistically significant.

# %%
from scipy.stats import pearsonr

# data
x = data.loc[:, "age"]
y = data.loc[:, "charges"]

# Calculate Pearson correlation coefficient and p-value
correlation_coefficient, p_value = pearsonr(x, y)

print("Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# Correlation Coefficient: 0.07969981747057353
# p-value: 0.011695909185032846

# %% [markdown]
# Interpretation of this relationship.
#
# Correlation coefficient is 0.08 which points to a very weak positive relationship. This means insurance charges tend to rise only slightly with age.
#
# Statistical significance:
#
# Since the p-value (≈0.012) is below the 0.05 threshold, the relationship is statistically significant.
#
# So the weak correlation is unlikely to be due to chance, but it is still a very small effect compared with BMI.

# %% [markdown]
# # Reflect
#
# Write a brief paragraph highlighting your process and the rationale to showcase critical thinking and problem-solving.
#
#
# The analysis provides strong evidence that out of the two factors— BMI and the number of children — BMI has a statistically significant effect on medical insurance costs. This is a crucial finding for the management team. It confirms that the insurer's criteria of using BMI as a factor for premium adjustment is supported by the data. The positive relationship suggests that as an individual's BMI increases, so do their likely insurance costs, providing a data-backed justification for a tiered pricing model. Similarly, older employees are statistically more likely to incur higher costs.
#
#
# In summary, the data clearly supports the management team's plan to develop more targeted insurance policies. The correlations found can be used to explain to employees why some may have to pay extra—it's based on objective, data-driven factors that have a significant impact on an insurer's costs.
#
# Limitations and Bias
# It is essential to present these findings with the following limitations in mind:
#
# Correlation does not imply causation: While a strong correlation exists, it does not prove that a high BMI directly causes high insurance costs. There may be other unobserved variables such as smoking status, chronic conditions  that influences both BMI and insurance charges. Without this additional data, a direct causal link cannot be established.
#
#
# Linearity assumption: Pearson correlation assumes a linear relationship. If the relationship is non-linear (e.g., costs rise sharply only above a certain BMI threshold), the correlation may underestimate the true association.
#
# Sensitivity to outliers: A few extreme values in charges (very high claims) can inflate or distort the correlation coefficient.
#
#
# In conclusion, the analysis provides robust statistical evidence to support a tiered insurance program. However, it's vital to frame this evidence correctly, acknowledging that it identifies strong correlations, not absolute causation, and is limited by the variables available in the dataset.
#
#
# Reflection on the Analysis Process
#
# Exploration
#
# I began by importing the dataset and performing initial descriptive statistics to understand the spread of variables such as age, BMI, number of children, and charges. Scatter plots were created to visually inspect relationships between each variable and insurance charges.
#
# Statistical testing
#
# I applied Pearson correlation (via scipy.stats.pearsonr) to quantify linear relationships between each predictor (age, BMI, number_of_children) and insurance charges. This provided both a correlation coefficient (r) and a p-value to test statistical significance.
#
# Interpretation:
#
# BMI showed a strong, statistically significant positive correlation with charges (r = 0.71, p < 0.001), making it the most important factor.
#
# Age showed a very weak but statistically significant positive correlation (r = 0.08, p = 0.012), suggesting only a minor influence.
#
# Number of children showed no significant correlation (r = 0.03, p = 0.33), indicating no meaningful impact on charges.
#
# Assumptions & limitations:
#
# Assumed linear relationships and no major data quality issues.
#
# Recognised limitations of correlation (cannot infer causality, sensitive to outliers).
#
# CONCLUSION:
#
# This analysis provides strong evidence that BMI is the key driver of insurance costs, with no influence from the number of children. While these correlations can help explain the basis for a tiered premium model, correlation analysis cannot prove causation. Therefore, potential fairness concerns regarding a BMI-based policy should still be considered carefully before implementation.
